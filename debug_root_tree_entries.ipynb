# %%
import uproot
import matplotlib.pyplot as plt

# %%
events_nominal = uproot.open('/eos/cms/store/group/phys_higgs/cmshgg/zhenxuan/Hgg_mass/MiniTree/UL2017/Summer20/DYMC2017_MiniTree_Syst_ptWgt_BDT_all.root')['DYToLL_13TeV_UntaggedTag']

# %%
events_nominal = uproot.open('/eos/cms/store/group/phys_higgs/cmshgg/zhenxuan/Hgg_mass/MiniTree/UL2017/Summer20/DYMC2017_MiniTree_Syst_ptWgt_BDT_all.root')['DYToLL_13TeV_UntaggedTag']
events_nominal_up = uproot.open('/eos/cms/store/group/phys_higgs/cmshgg/zhenxuan/Hgg_mass/MiniTree/UL2017/Summer20/DYMC2017_MiniTree_Syst_ptWgt_BDT_all.root')['DYToLL_13TeV_UntaggedTag_MvaShiftUp01sigma']
events_nominal_down = uproot.open('/eos/cms/store/group/phys_higgs/cmshgg/zhenxuan/Hgg_mass/MiniTree/UL2017/Summer20/DYMC2017_MiniTree_Syst_ptWgt_BDT_all.root')['DYToLL_13TeV_UntaggedTag_MvaShiftDown01sigma']

# %%
plt.figure(figsize=(10,10))
plt.hist(events_nominal_up.arrays(['Tran_DiphotonMVA_self']).Tran_DiphotonMVA_self, label='up', histtype='step')
plt.hist(events_nominal_down.arrays(['Tran_DiphotonMVA_self']).Tran_DiphotonMVA_self, label='down', histtype='step')
plt.hist(events_nominal.arrays(['Tran_DiphotonMVA_self']).Tran_DiphotonMVA_self, label='nominal', histtype='step')
plt.legend()

# %%
plt.figure(figsize=(10,10))
plt.hist(events_nominal_up.arrays(['Tran_DiphotonMVA_self']).Tran_DiphotonMVA_self, label='up', histtype='step', density=True)
plt.hist(events_nominal_down.arrays(['Tran_DiphotonMVA_self']).Tran_DiphotonMVA_self, label='down', histtype='step', density=True)
plt.hist(events_nominal.arrays(['Tran_DiphotonMVA_self']).Tran_DiphotonMVA_self, label='nominal', histtype='step', density=True)
plt.legend()

# %%
events.keys()

# %%
events.keys()
# Out:
# ['DYToLL_13TeV_UntaggedTag;1',
#  'DYToLL_13TeV_UntaggedTag_MvaShiftUp01sigma;1',
#  'DYToLL_13TeV_UntaggedTag_MvaShiftDown01sigma;1',
#  'DYToLL_13TeV_UntaggedTag_SigmaEOverEShiftDown01sigma;1',
#  'DYToLL_13TeV_UntaggedTag_SigmaEOverEShiftUp01sigma;1']
